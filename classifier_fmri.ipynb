# %%
from  problem import get_train_data

data_train, labels_train = get_train_data()
data_train.head()
# Out:
#                       participants_site participants_sex  participants_age  \
# subject_id
# 1932355398536124106                   5                F          9.301370
# 5174041730092253771                  19                M         29.000000
# 10219322676643534800                 19                F         45.000000
# 10645466564919190227                  5                F          9.216438
# 14512541342641936232                 28                M         15.050000
#
#                       anatomy_lh_bankssts_area  \
# subject_id
# 1932355398536124106                      977.0
# 5174041730092253771                     1279.0
# 10219322676643534800                     926.0
# 10645466564919190227                     983.0
# 14512541342641936232                    1488.0
#
#                       anatomy_lh_caudalanteriorcingulate_area  \
# subject_id
# 1932355398536124106                                     427.0
# 5174041730092253771                                     730.0
# ...

# %%
data_train_functional = data_train[[col for col in data_train.columns if col.startswith('fmri')]]
data_train_functional.head()
import numpy as np
import pandas as pd
from download_data import fetch_fmri_time_series
#fetch_fmri_time_series(atlas='msdl')
#fmri_data = data_train_functional[[col for col in data.columns if col.startswith('fmri')]]
fmri_msdl_filenames= data_train_functional['fmri_msdl']
fmri= np.array([pd.read_csv(subject_filename,header=None).values
                    for subject_filename in fmri_msdl_filenames])
np.save('data/autism_fmri_ts.npy', fmri)

# %%
X1=np.load('data/autism_fmri_ts.npy')
X1.shape
print(X1)
# Out:
# [array([[-170.58418904, -251.28715046, -125.46264306, ...,  285.65962205,
#           55.70167391,  101.8019803 ],
#        [-165.11213069, -220.35295754, -152.20183265, ...,  153.14797847,
#           60.8414484 ,   80.19048164],
#        [ -46.14451381, -132.13783535,  -34.33447537, ...,   14.02945433,
#           71.60656788,   46.44475149],
#        ...,
#        [ 109.744777  ,   42.840746  ,  -65.14305054, ...,   27.24000552,
#          148.02891149,   55.09326411],
#        [ 121.98589719,   63.99658882,   56.90057242, ..., -350.98144061,
#          -39.70115335, -223.34738755],
#        [ 142.18491229,   66.17019465,   66.39247316, ..., -321.01194667,
#         -146.03171305, -274.75569673]])
#  array([[  90.37441482,   53.31538016,   66.96818655, ...,  -23.58191296,
#          -91.2886984 , -114.81020401],
#        [  78.44119126,   58.22487275,   52.02860368, ...,  -27.7554954 ,
#         -106.30852145, -134.81883696],
# ...

# %%
fmri_basc064_filenames= data_train_functional['fmri_basc064']
fmri_basc= np.array([pd.read_csv(subject_filename,header=None).values
                    for subject_filename in fmri_basc064_filenames])
np.save('data/autism_fmri_basc064_ts.npy', fmri_basc)

# %%
X2=np.load('data/autism_fmri_basc064_ts.npy')
X2.shape
# Out:
# (1127,)

# %%
fmri_basc122_filenames= data_train_functional['fmri_basc122']
fmri_basc1= np.array([pd.read_csv(subject_filename,header=None).values
                    for subject_filename in fmri_basc122_filenames])
np.save('data/autism_fmri_basc122_ts.npy', fmri_basc1)

# %%
X3=np.load('data/autism_fmri_basc122_ts.npy')
X3.shape
# Out:
# (1127,)

# %%
fmri_basc197_filenames= data_train_functional['fmri_basc197']
fmri_basc2= np.array([pd.read_csv(subject_filename,header=None).values
                    for subject_filename in fmri_basc197_filenames])
np.save('data/autism_fmri_basc197_ts.npy', fmri_basc2)

# %%
X4=np.load('data/autism_fmri_basc197_ts.npy')
X4.shape
# Out:
# (1127,)

# %%
fmri_craddock_filenames= data_train_functional['fmri_craddock_scorr_mean']
fmri_crad= np.array([pd.read_csv(subject_filename,header=None).values
                    for subject_filename in fmri_craddock_filenames])
np.save('data/autism_fmri_craddock_ts.npy', fmri_crad)

# %%
X5=np.load('data/autism_fmri_craddock_ts.npy')
X5.shape
# Out:
# (1127,)

# %%
fmri_harvard_filenames= data_train_functional['fmri_harvard_oxford_cort_prob_2mm']
fmri_harvard= np.array([pd.read_csv(subject_filename,header=None).values
                    for subject_filename in fmri_harvard_filenames])
np.save('data/autism_fmri_harvard_ts.npy', fmri_harvard)

# %%
X6=np.load('data/autism_fmri_harvard_ts.npy')
X6.shape
# Out:
# (1127,)

# %%
fmri_power_filenames= data_train_functional['fmri_power_2011']
fmri_power= np.array([pd.read_csv(subject_filename,header=None).values
                    for subject_filename in fmri_power_filenames])
np.save('data/autism_fmri_power_ts.npy', fmri_power)

# %%
X7=np.load('data/autism_fmri_power_ts.npy')
X7.shape
# Out:
# (1127,)

# %%
fmri_motions_filenames= data_train_functional['fmri_motions']
fmri_motion= np.array([pd.read_csv(subject_filename,header=None).values
                    for subject_filename in fmri_motions_filenames])
np.save('data/autism_fmri_motions_ts.npy', fmri_motion)

# %%
X8=np.load('data/autism_fmri_motions_ts.npy')
X8.shape
# Out:
# (1127,)

# %%
L = (X1,X2,X3,X4,X5,X6,X7,X8)
arr = np.vstack(L)
arr.shape
X_train= np.transpose(arr)
X_train.shape
# Out:
# (1127, 8)

# %%
print(labels_train)
# Out:
# [0 0 1 ... 0 1 0]

# %%
from problem import get_test_data
data_test, labels_test = get_test_data()
data_test.head()
Y1 = data_test[[col for col in data_train.columns if col.startswith('fmri')]]
Y_test=Y1.drop(['fmri_select'], axis=1)
Y_test.head()
import numpy as np
import pandas as pd
from download_data import fetch_fmri_time_series
#fetch_fmri_time_series(atlas='msdl')
#fmri_data = data_train_functional[[col for col in data.columns if col.startswith('fmri')]]
fmri_msdl_test_filenames= Y_test['fmri_msdl']
fmri= np.array([pd.read_csv(subject_filename,header=None).values
                    for subject_filename in fmri_msdl_test_filenames])
np.save('data/autism_fmri_ts_test.npy', fmri)
X1=np.load('data/autism_fmri_ts_test.npy')
X1.shape
fmri_basc064_test_filenames= Y_test['fmri_basc064']
fmri_basc= np.array([pd.read_csv(subject_filename,header=None).values
                    for subject_filename in fmri_basc064_test_filenames])
np.save('data/autism_fmri_basc064_ts_test.npy', fmri_basc)
X2=np.load('data/autism_fmri_basc064_ts_test.npy')
X2.shape
fmri_basc122_test_filenames= Y_test['fmri_basc122']
fmri_basc1= np.array([pd.read_csv(subject_filename,header=None).values
                    for subject_filename in fmri_basc122_test_filenames])
np.save('data/autism_fmri_basc122_ts_test.npy', fmri_basc1)
X3=np.load('data/autism_fmri_basc122_ts_test.npy')
X3.shape
fmri_basc197_test_filenames= Y_test['fmri_basc197']
fmri_basc2= np.array([pd.read_csv(subject_filename,header=None).values
                    for subject_filename in fmri_basc197_test_filenames])
np.save('data/autism_fmri_basc197_ts_test.npy', fmri_basc2)
X4=np.load('data/autism_fmri_basc197_ts_test.npy')
X4.shape
fmri_craddock_test_filenames= Y_test['fmri_craddock_scorr_mean']
fmri_crad= np.array([pd.read_csv(subject_filename,header=None).values
                    for subject_filename in fmri_craddock_test_filenames])
np.save('data/autism_fmri_craddock_ts_test.npy', fmri_crad)
X5=np.load('data/autism_fmri_craddock_ts_test.npy')
X5.shape
fmri_harvard_test_filenames= Y_test['fmri_harvard_oxford_cort_prob_2mm']
fmri_harvard= np.array([pd.read_csv(subject_filename,header=None).values
                    for subject_filename in fmri_harvard_test_filenames])
np.save('data/autism_fmri_harvard_ts_test.npy', fmri_harvard)
X6=np.load('data/autism_fmri_harvard_ts_test.npy')
X6.shape
fmri_power_test_filenames= Y_test['fmri_power_2011']
fmri_power= np.array([pd.read_csv(subject_filename,header=None).values
                    for subject_filename in fmri_power_test_filenames])
np.save('data/autism_fmri_power_ts_test.npy', fmri_power)
X7=np.load('data/autism_fmri_power_ts_test.npy')
X7.shape
fmri_motions_test_filenames= Y_test['fmri_motions']
fmri_motion= np.array([pd.read_csv(subject_filename,header=None).values
                    for subject_filename in fmri_motions_test_filenames])
np.save('data/autism_fmri_motions_ts_test.npy', fmri_motion)
X8=np.load('data/autism_fmri_motions_ts_test.npy')
X8.shape
L = (X1,X2,X3,X4,X5,X6,X7,X8)
arr = np.vstack(L)
arr.shape
Y_testdata= np.transpose(arr)
Y_testdata.shape
# Out:
# (23, 8)

# %%
print (X_train.shape, labels_train.shape)
print (Y_testdata.shape, labels_test.shape)
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn import model_selection, datasets, svm
# Out:
# (1127, 8) (1127,)
# (23, 8) (23,)

# %%
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Input
from keras.models import Model

# %%
classifier = Sequential()
#classifier.add(Flatten(input_shape=(1127,8)))
classifier.add(Dense(output_dim = 4, init = 'uniform', activation = 'relu', input_shape = (1,8)))
#classifier.add(Dense(output_dim = 250, init = 'uniform', activation = 'relu'))
#classifier.add(Dense(output_dim = 125, init = 'uniform', activation = 'relu'))
#classifier.add(Dense(output_dim = 65, init = 'uniform', activation = 'relu'))
#classifier.add(Dense(output_dim = 38, init = 'uniform', activation = 'relu'))
#classifier.add(Dense(output_dim = 14, init = 'uniform', activation = 'relu'))
classifier.add(Dense(output_dim = 2, init = 'uniform', activation = 'relu'))
classifier.add(Dense(output_dim = 1, init = 'uniform', activation = 'sigmoid'))
classifier.add(Flatten())
#classifier.add(Dense(output_dim = 2, init = 'uniform', activation = 'relu'))
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

classifier.fit(X_train, labels_train, batch_size = 10 , nb_epoch = 100)
scores = classifier.evaluate(X_train, labels_train)
print("\n%s: %.2f%%" % (classifier.metrics_names[1], scores[1]*100))
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_shape=(1, 8), units=4, kernel_initializer="uniform")`
#   after removing the cwd from sys.path.
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=2, kernel_initializer="uniform")`
#   # Remove the CWD from sys.path while we load stuff.
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1, kernel_initializer="uniform")`
#   # This is added back by InteractiveShellApp.init_path()
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   app.launch_new_instance()
# Epoch 1/100
# 1127/1127 [==============================] - 2s 2ms/step - loss: 0.6930 - acc: 0.5209
# ...

# %%
y_pred = classifier.predict(Y_testdata, batch_size=10, steps)
y_pred = (y_pred > 0.5)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(labels_test, y_pred)

# %%
#incomplete###
